# %% [markdown]
# ## Pandas Minimal Example
#
# This is a snip from <a href=https://cognitiveclass.ai/courses/machine-learning-with-python> IBM's AI course. </a>
#
# Data is gathered with `!wget`, organized with `pandas`, and then plotted with `matplotlib`

# %%
import pandas, matplotlib

# !wget -O FuelConsumption.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/FuelConsumptionCo2.csv 

data_frame = pandas.read_csv('FuelConsumption.csv');

matplotlib.pyplot.scatter(data_frame.ENGINESIZE, data_frame.CO2EMISSIONS, color='blue');
# Out:
# --2019-10-14 11:07:08--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/FuelConsumptionCo2.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.193
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72629 (71K) [text/csv]
# Saving to: ‘FuelConsumption.csv’
#
# FuelConsumption.csv 100%[===================>]  70.93K  --.-KB/s    in 0.1s
#
# 2019-10-14 11:07:09 (736 KB/s) - ‘FuelConsumption.csv’ saved [72629/72629]
